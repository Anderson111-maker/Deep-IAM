# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tsgm
import tensorflow as tf
from tensorflow import keras
import time

# %%
#Save Kyoto_Gases data (2020-2100), consider the case of C1-C8 for simplicity.
Kyoto_Gases = pd.read_csv('Kyoto Gases.csv')
Kyoto_Gases = Kyoto_Gases[Kyoto_Gases['Category'].isin(['C1','C2','C3','C4','C5','C6','C7','C8'])]
mapping = {'C1':0,'C2':0,'C3':0,'C4':0,'C5':1,'C6':1,'C7':2,'C8':2}#Aggregate categories into 3 categories, with 0-2 corresponding to C1234-C78, respectively
Kyoto_Gases['Category'].replace(mapping,inplace=True)
Kyoto_Gases.reset_index(drop=True,inplace=True)
Kyoto_Gases.drop(columns=['Category_name'],inplace = True)

# %%
#Load a dataset of individual variables
CarbonSequestration = pd.read_csv('Carbon_Sequestration_CCS_imputed.csv')
FinalEnergy_Liquid = pd.read_csv('Final Energy_Liquids.csv')
PrimaryEnergy_Gas = pd.read_csv('Primary Energy_Gas.csv')
PrimaryEnergy_Oil = pd.read_csv('Primary Energy_Oil.csv')
PrimaryEnergy_Coal = pd.read_csv('PrimaryEnergy_Coal.csv')
SecondaryEle_Nuclear = pd.read_csv('SecondaryEnergy_Electricity_Nuclear.csv')
SecondaryEle_Hydro = pd.read_csv('SecondaryEnergy_Electricity_Hydro.csv')
SecondaryEle = pd.read_csv('SecondaryEnergy_Electricity.csv')
SecondaryEle_Oil = pd.read_csv('SecondaryEnergy_Electricity_Oil.csv')
SecondaryEle_Coal = pd.read_csv('SecondaryEnergy_Electricity_Coal.csv')
SecondaryEle_Gas = pd.read_csv('SecondaryEnergy_Electricity_Gas.csv')
SecondaryEle_Wind = pd.read_csv('SecondaryEnergy_Electricity_Wind.csv')
SecondaryEle_Solar = pd.read_csv('SecondaryEnergy_Electricity_Solar.csv')
SecondaryEle_Biomass = pd.read_csv('SecondaryEnergy_Electricity_Biomass.csv')
SecondaryEle_Geothermal = pd.read_csv('SecondaryEnergy_Electricity_Geothermal.csv')

# %%
#Get the intersection of the models and scenarios contained in each variable
Model_Scenario = Kyoto_Gases[['Model','Scenario']]
Variables = [CarbonSequestration,FinalEnergy_Liquid,PrimaryEnergy_Coal,PrimaryEnergy_Gas,PrimaryEnergy_Oil,SecondaryEle_Nuclear,
            SecondaryEle_Oil,SecondaryEle_Solar,SecondaryEle_Wind,SecondaryEle_Hydro,SecondaryEle_Geothermal,SecondaryEle_Gas,
            SecondaryEle_Coal,SecondaryEle_Biomass,SecondaryEle]
for variable in Variables:
    Model_Scenario = pd.merge(Model_Scenario,variable[['Model','Scenario']],on=['Model','Scenario'],how='inner')

# %%
for i in range(len(Variables)):
    Variables[i] = pd.merge(Model_Scenario,Variables[i],on=['Model','Scenario'],how='inner')
for i in range(len(Variables)):
    Variables[i].drop(columns=['Category_name'],inplace = True)

# %%
Kyoto_Gases = pd.merge(Kyoto_Gases,Model_Scenario,on = ['Model','Scenario'],how = 'inner')

# %%
Variables.append(Kyoto_Gases)
data_num = Variables[0].shape[0]

# %%
#ntf:the num of feature
nft = len(Variables)

X = np.zeros((data_num,9,nft))
for i in range(nft):
    Variables[i] = Variables[i].iloc[:,3:-1].values
    
for i in range(data_num):
    for j in range(9):
        for k in range(nft):
            X[i][j][k] = (Variables[k])[i,j]

# %%
Y = Kyoto_Gases['Category'].values

# %%
#Separate datasets by category. But the training process does not distinguish between categories like VAE
C1234_DataSet = X[Y == 0]
C56_DataSet = X[Y == 1]
C78_DataSet = X[Y == 2]
#the num of C1234,C56,C78
C1234_DataSet.shape[0],C56_DataSet.shape[0],C78_DataSet.shape[0]
# Out:
# (554, 237, 110)

# %%
#Set problem parameters
latent_dim = 38
output_dim = 3
feature_dim = nft
seq_len = 9
batch_size = 100
generator_in_channels = latent_dim + output_dim
discriminator_in_channels = feature_dim + output_dim

# %%
#Standardize the data and compress it to (0, 1).
scaler = tsgm.utils.TSFeatureWiseScaler((0,1))
X_train = scaler.fit_transform(X)
Y_train = keras.utils.to_categorical(Y, 3)

X_train = X_train.astype(np.float32)
Y_train = Y_train.astype(np.float32)

dataset = tf.data.Dataset.from_tensor_slices((X_train, Y_train))
dataset = dataset.shuffle(buffer_size=1024).batch(batch_size)

# %%
architecture = tsgm.models.architectures.zoo["cgan_base_c4_l1"](
    seq_len=seq_len, feat_dim=feature_dim,
    latent_dim=latent_dim, output_dim=output_dim)
discriminator, generator = architecture.discriminator, architecture.generator

# %%
#Define an optimization strategy

lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=1e-4,#
    decay_steps=200,#200
    decay_rate=0.95)#0.95

cond_gan = tsgm.models.cgan.ConditionalGAN(
    discriminator=discriminator, generator=generator, latent_dim=latent_dim
)
cond_gan.compile(
    d_optimizer=keras.optimizers.Adam(lr_schedule),
    g_optimizer=keras.optimizers.Adam(lr_schedule),
    loss_fn=keras.losses.BinaryCrossentropy(),
)

cgan_start = time.time()
cond_gan.fit(dataset, epochs=1500)
cgan_end = time.time()

runtime = cgan_end - cgan_start
with open('Runtime.txt', 'a') as f:
    f.write(f'CGAN-SecondaryEle-traing time: {runtime:.4f} sec\n')
# Out:
# Epoch 1/1500
# 10/10 [==============================] - 10s 527ms/step - g_loss: 0.6931 - d_loss: 0.6807
# Epoch 2/1500
# 10/10 [==============================] - 5s 528ms/step - g_loss: 0.7065 - d_loss: 0.6455
# Epoch 3/1500
# 10/10 [==============================] - 6s 541ms/step - g_loss: 0.7242 - d_loss: 0.6072
# Epoch 4/1500
# 10/10 [==============================] - 6s 584ms/step - g_loss: 0.7106 - d_loss: 0.5789
# Epoch 5/1500
# 10/10 [==============================] - 6s 561ms/step - g_loss: 0.3907 - d_loss: 0.8001
# Epoch 6/1500
# 10/10 [==============================] - 6s 548ms/step - g_loss: 0.3706 - d_loss: 0.8858
# Epoch 7/1500
# 10/10 [==============================] - 6s 555ms/step - g_loss: 0.6630 - d_loss: 0.7008
# Epoch 8/1500
# 10/10 [==============================] - 6s 553ms/step - g_loss: 1.0309 - d_loss: 0.5679
# Epoch 9/1500
# 10/10 [==============================] - 6s 558ms/step - g_loss: 1.2863 - d_loss: 0.4963
# Epoch 10/1500
# 10/10 [==============================] - 6s 572ms/step - g_loss: 1.3209 - d_loss: 0.4694
# Epoch 11/1500
# 10/10 [==============================] - 6s 569ms/step - g_loss: 1.2004 - d_loss: 0.4895
# Epoch 12/1500
# 10/10 [==============================] - 6s 552ms/step - g_loss: 1.0409 - d_loss: 0.5557
# Epoch 13/1500
# 10/10 [==============================] - 6s 552ms/step - g_loss: 0.7216 - d_loss: 0.7306
# Epoch 14/1500
# 10/10 [==============================] - 6s 569ms/step - g_loss: 0.5427 - d_loss: 0.8872
# Epoch 15/1500
# 10/10 [==============================] - 6s 574ms/step - g_loss: 0.5884 - d_loss: 0.8458
# Epoch 16/1500
# 10/10 [==============================] - 6s 613ms/step - g_loss: 0.6396 - d_loss: 0.7693
# Epoch 17/1500
# 10/10 [==============================] - 6s 605ms/step - g_loss: 0.7264 - d_loss: 0.6935
# Epoch 18/1500
# 10/10 [==============================] - 6s 566ms/step - g_loss: 0.8548 - d_loss: 0.6266
# Epoch 19/1500
# 10/10 [==============================] - 6s 599ms/step - g_loss: 0.9636 - d_loss: 0.5719
# Epoch 20/1500
# 10/10 [==============================] - 7s 669ms/step - g_loss: 1.0032 - d_loss: 0.5391
# Epoch 21/1500
# 10/10 [==============================] - 6s 559ms/step - g_loss: 0.9682 - d_loss: 0.5354
# Epoch 22/1500
# 10/10 [==============================] - 6s 603ms/step - g_loss: 0.9238 - d_loss: 0.5495
# Epoch 23/1500
# 10/10 [==============================] - 6s 615ms/step - g_loss: 0.9817 - d_loss: 0.5467
# Epoch 24/1500
# 10/10 [==============================] - 6s 573ms/step - g_loss: 0.9060 - d_loss: 0.5954
# Epoch 25/1500
# 10/10 [==============================] - 6s 608ms/step - g_loss: 0.8059 - d_loss: 0.6738
# Epoch 26/1500
# 10/10 [==============================] - 6s 630ms/step - g_loss: 0.8246 - d_loss: 0.6848
# Epoch 27/1500
# 10/10 [==============================] - 7s 639ms/step - g_loss: 0.8734 - d_loss: 0.6734
# Epoch 28/1500
# 10/10 [==============================] - 6s 631ms/step - g_loss: 0.7512 - d_loss: 0.7330
# Epoch 29/1500
# 10/10 [==============================] - 6s 604ms/step - g_loss: 0.6563 - d_loss: 0.7693
# Epoch 30/1500
# 10/10 [==============================] - 6s 621ms/step - g_loss: 0.6718 - d_loss: 0.7289
# Epoch 31/1500
# 10/10 [==============================] - 7s 659ms/step - g_loss: 0.6716 - d_loss: 0.7115
# Epoch 32/1500
# 10/10 [==============================] - 7s 713ms/step - g_loss: 0.6555 - d_loss: 0.7249
# Epoch 33/1500
# 10/10 [==============================] - 7s 648ms/step - g_loss: 0.6861 - d_loss: 0.7207
# Epoch 34/1500
# 10/10 [==============================] - 6s 636ms/step - g_loss: 0.7270 - d_loss: 0.7034
# Epoch 35/1500
# 10/10 [==============================] - 6s 627ms/step - g_loss: 0.7409 - d_loss: 0.6889
# Epoch 36/1500
# 10/10 [==============================] - 7s 645ms/step - g_loss: 0.7178 - d_loss: 0.6928
# Epoch 37/1500
# 10/10 [==============================] - 6s 632ms/step - g_loss: 0.6855 - d_loss: 0.7085
# Epoch 38/1500
# 10/10 [==============================] - 7s 652ms/step - g_loss: 0.6695 - d_loss: 0.7165
# Epoch 39/1500
# 10/10 [==============================] - 7s 711ms/step - g_loss: 0.6851 - d_loss: 0.7053
# Epoch 40/1500
# 10/10 [==============================] - 7s 640ms/step - g_loss: 0.7107 - d_loss: 0.6906
# Epoch 41/1500
# 10/10 [==============================] - 7s 693ms/step - g_loss: 0.7082 - d_loss: 0.6922
# Epoch 42/1500
# 10/10 [==============================] - 7s 641ms/step - g_loss: 0.6851 - d_loss: 0.7019
# Epoch 43/1500
# 10/10 [==============================] - 7s 662ms/step - g_loss: 0.6799 - d_loss: 0.6986
# Epoch 44/1500
# 10/10 [==============================] - 7s 649ms/step - g_loss: 0.6833 - d_loss: 0.6910
# Epoch 45/1500
# 10/10 [==============================] - 7s 662ms/step - g_loss: 0.6980 - d_loss: 0.6854
# Epoch 46/1500
# 10/10 [==============================] - 7s 652ms/step - g_loss: 0.7091 - d_loss: 0.6869
# Epoch 47/1500
# 10/10 [==============================] - 7s 652ms/step - g_loss: 0.7092 - d_loss: 0.6883
# Epoch 48/1500
# 10/10 [==============================] - 7s 662ms/step - g_loss: 0.7060 - d_loss: 0.6852
# Epoch 49/1500
# 10/10 [==============================] - 7s 646ms/step - g_loss: 0.7173 - d_loss: 0.6802
# Epoch 50/1500
# 10/10 [==============================] - 7s 693ms/step - g_loss: 0.7307 - d_loss: 0.6788
# Epoch 51/1500
# 10/10 [==============================] - 7s 654ms/step - g_loss: 0.7318 - d_loss: 0.6815
# Epoch 52/1500
# 10/10 [==============================] - 7s 657ms/step - g_loss: 0.7307 - d_loss: 0.6862
# Epoch 53/1500
# 10/10 [==============================] - 7s 681ms/step - g_loss: 0.7332 - d_loss: 0.6905
# Epoch 54/1500
# 10/10 [==============================] - 7s 654ms/step - g_loss: 0.7292 - d_loss: 0.6942
# Epoch 55/1500
# 10/10 [==============================] - 7s 670ms/step - g_loss: 0.7294 - d_loss: 0.6940
# Epoch 56/1500
# 10/10 [==============================] - 7s 703ms/step - g_loss: 0.7324 - d_loss: 0.6844
# Epoch 57/1500
# 10/10 [==============================] - 7s 672ms/step - g_loss: 0.7396 - d_loss: 0.6746
# Epoch 58/1500
# 10/10 [==============================] - 7s 694ms/step - g_loss: 0.7501 - d_loss: 0.6701
# Epoch 59/1500
# 10/10 [==============================] - 7s 712ms/step - g_loss: 0.7535 - d_loss: 0.6640
# Epoch 60/1500
# 10/10 [==============================] - 7s 692ms/step - g_loss: 0.7388 - d_loss: 0.6643
# Epoch 61/1500
# 10/10 [==============================] - 7s 717ms/step - g_loss: 0.7334 - d_loss: 0.6619
# Epoch 62/1500
# 10/10 [==============================] - 7s 706ms/step - g_loss: 0.7387 - d_loss: 0.6637
# Epoch 63/1500
# 10/10 [==============================] - 7s 661ms/step - g_loss: 0.7651 - d_loss: 0.6604
# Epoch 64/1500
# 10/10 [==============================] - 7s 681ms/step - g_loss: 0.7671 - d_loss: 0.6566
# Epoch 65/1500
# 10/10 [==============================] - 7s 698ms/step - g_loss: 0.7487 - d_loss: 0.6577
# Epoch 66/1500
# 10/10 [==============================] - 7s 714ms/step - g_loss: 0.7375 - d_loss: 0.6530
# Epoch 67/1500
# 10/10 [==============================] - 7s 716ms/step - g_loss: 0.7488 - d_loss: 0.6498
# Epoch 68/1500
# 10/10 [==============================] - 7s 690ms/step - g_loss: 0.7849 - d_loss: 0.6499
# Epoch 69/1500
# 10/10 [==============================] - 7s 668ms/step - g_loss: 0.7860 - d_loss: 0.6538
# Epoch 70/1500
# 10/10 [==============================] - 7s 708ms/step - g_loss: 0.7578 - d_loss: 0.6430
# Epoch 71/1500
# 10/10 [==============================] - 7s 688ms/step - g_loss: 0.7540 - d_loss: 0.6343
# Epoch 72/1500
# 10/10 [==============================] - 7s 675ms/step - g_loss: 0.7777 - d_loss: 0.6261
# Epoch 73/1500
# 10/10 [==============================] - 7s 703ms/step - g_loss: 0.7814 - d_loss: 0.6271
# Epoch 74/1500
# 10/10 [==============================] - 7s 646ms/step - g_loss: 0.7920 - d_loss: 0.6216
# Epoch 75/1500
# 10/10 [==============================] - 7s 671ms/step - g_loss: 0.8068 - d_loss: 0.6093
# Epoch 76/1500
# 10/10 [==============================] - 7s 687ms/step - g_loss: 0.8385 - d_loss: 0.5887
# Epoch 77/1500
# 10/10 [==============================] - 7s 645ms/step - g_loss: 0.8331 - d_loss: 0.5886
# Epoch 78/1500
# 10/10 [==============================] - 6s 638ms/step - g_loss: 0.8703 - d_loss: 0.6143
# Epoch 79/1500
# 10/10 [==============================] - 7s 667ms/step - g_loss: 0.8562 - d_loss: 0.6394
# Epoch 80/1500
# 10/10 [==============================] - 7s 695ms/step - g_loss: 0.8332 - d_loss: 0.6326
# Epoch 81/1500
# 10/10 [==============================] - 7s 690ms/step - g_loss: 1.0489 - d_loss: 0.5547
# Epoch 82/1500
# 10/10 [==============================] - 7s 721ms/step - g_loss: 0.9404 - d_loss: 0.5230
# Epoch 83/1500
# 10/10 [==============================] - 7s 695ms/step - g_loss: 0.7268 - d_loss: 0.6219
# Epoch 84/1500
# 10/10 [==============================] - 7s 722ms/step - g_loss: 0.7678 - d_loss: 0.6949
# Epoch 85/1500
# 10/10 [==============================] - 7s 710ms/step - g_loss: 0.9062 - d_loss: 0.6788
# Epoch 86/1500
# 10/10 [==============================] - 7s 714ms/step - g_loss: 0.8396 - d_loss: 0.6608
# Epoch 87/1500
# 10/10 [==============================] - 7s 692ms/step - g_loss: 0.8301 - d_loss: 0.6455
# Epoch 88/1500
# 10/10 [==============================] - 7s 657ms/step - g_loss: 0.9701 - d_loss: 0.5924
# Epoch 89/1500
# 10/10 [==============================] - 7s 698ms/step - g_loss: 0.9374 - d_loss: 0.5755
# Epoch 90/1500
# 10/10 [==============================] - 7s 687ms/step - g_loss: 0.8781 - d_loss: 0.5740
# Epoch 91/1500
# 10/10 [==============================] - 7s 685ms/step - g_loss: 0.8836 - d_loss: 0.5768
# Epoch 92/1500
# 10/10 [==============================] - 7s 711ms/step - g_loss: 0.9299 - d_loss: 0.5894
# Epoch 93/1500
# 10/10 [==============================] - 7s 715ms/step - g_loss: 0.8714 - d_loss: 0.5892
# Epoch 94/1500
# 10/10 [==============================] - 7s 682ms/step - g_loss: 0.8171 - d_loss: 0.6105
# Epoch 95/1500
# 10/10 [==============================] - 7s 650ms/step - g_loss: 0.8438 - d_loss: 0.6137
# Epoch 96/1500
# 10/10 [==============================] - 7s 707ms/step - g_loss: 0.8261 - d_loss: 0.5910
# Epoch 97/1500
# 10/10 [==============================] - 7s 698ms/step - g_loss: 0.7789 - d_loss: 0.6432
# Epoch 98/1500
# 10/10 [==============================] - 7s 701ms/step - g_loss: 0.6661 - d_loss: 0.7551
# Epoch 99/1500
# 10/10 [==============================] - 7s 707ms/step - g_loss: 0.6510 - d_loss: 0.8077
# Epoch 100/1500
# 10/10 [==============================] - 7s 708ms/step - g_loss: 0.6353 - d_loss: 0.8054
# Epoch 101/1500
# 10/10 [==============================] - 7s 688ms/step - g_loss: 0.6679 - d_loss: 0.7767
# Epoch 102/1500
# 10/10 [==============================] - 7s 694ms/step - g_loss: 0.6934 - d_loss: 0.7522
# Epoch 103/1500
# 10/10 [==============================] - 8s 767ms/step - g_loss: 0.7318 - d_loss: 0.7369
# Epoch 104/1500
# 10/10 [==============================] - 7s 719ms/step - g_loss: 0.7025 - d_loss: 0.7240
# Epoch 105/1500
# 10/10 [==============================] - 7s 712ms/step - g_loss: 0.7011 - d_loss: 0.7092
# Epoch 106/1500
# 10/10 [==============================] - 7s 725ms/step - g_loss: 0.6940 - d_loss: 0.7094
# Epoch 107/1500
# 10/10 [==============================] - 7s 723ms/step - g_loss: 0.6465 - d_loss: 0.7234
# Epoch 108/1500
# 10/10 [==============================] - 7s 693ms/step - g_loss: 0.7154 - d_loss: 0.7095
# Epoch 109/1500
# 10/10 [==============================] - 7s 706ms/step - g_loss: 0.7177 - d_loss: 0.7131
# Epoch 110/1500
# 10/10 [==============================] - 7s 711ms/step - g_loss: 0.6895 - d_loss: 0.7143
# Epoch 111/1500
# 10/10 [==============================] - 8s 747ms/step - g_loss: 0.6985 - d_loss: 0.7023
# Epoch 112/1500
# 10/10 [==============================] - 7s 716ms/step - g_loss: 0.7071 - d_loss: 0.6880
# Epoch 113/1500
# 10/10 [==============================] - 8s 770ms/step - g_loss: 0.7079 - d_loss: 0.6854
# Epoch 114/1500
# 10/10 [==============================] - 7s 724ms/step - g_loss: 0.6947 - d_loss: 0.6964
# Epoch 115/1500
# 10/10 [==============================] - 8s 758ms/step - g_loss: 0.6710 - d_loss: 0.7082
# Epoch 116/1500
# 10/10 [==============================] - 7s 728ms/step - g_loss: 0.6527 - d_loss: 0.7250
# Epoch 117/1500
# 10/10 [==============================] - 7s 697ms/step - g_loss: 0.6621 - d_loss: 0.7274
# Epoch 118/1500
# 10/10 [==============================] - 7s 713ms/step - g_loss: 0.6683 - d_loss: 0.7273
# Epoch 119/1500
# 10/10 [==============================] - 7s 698ms/step - g_loss: 0.6623 - d_loss: 0.7213
# Epoch 120/1500
# 10/10 [==============================] - 8s 761ms/step - g_loss: 0.6560 - d_loss: 0.7108
# Epoch 121/1500
# 10/10 [==============================] - 7s 729ms/step - g_loss: 0.6620 - d_loss: 0.7032
# Epoch 122/1500
# 10/10 [==============================] - 7s 741ms/step - g_loss: 0.6841 - d_loss: 0.6978
# Epoch 123/1500
# 10/10 [==============================] - 7s 709ms/step - g_loss: 0.7027 - d_loss: 0.6921
# Epoch 124/1500
# 10/10 [==============================] - 8s 762ms/step - g_loss: 0.7119 - d_loss: 0.6943
# Epoch 125/1500
# 10/10 [==============================] - 7s 686ms/step - g_loss: 0.7242 - d_loss: 0.6963
# Epoch 126/1500
# 10/10 [==============================] - 8s 812ms/step - g_loss: 0.7144 - d_loss: 0.6946
# Epoch 127/1500
# 10/10 [==============================] - 8s 737ms/step - g_loss: 0.6999 - d_loss: 0.6926
# Epoch 128/1500
# 10/10 [==============================] - 7s 692ms/step - g_loss: 0.6970 - d_loss: 0.6917
# Epoch 129/1500
# 10/10 [==============================] - 7s 720ms/step - g_loss: 0.6885 - d_loss: 0.6898
# Epoch 130/1500
# 10/10 [==============================] - 7s 692ms/step - g_loss: 0.6760 - d_loss: 0.6883
# Epoch 131/1500
# 10/10 [==============================] - 8s 747ms/step - g_loss: 0.6769 - d_loss: 0.6895
# Epoch 132/1500
# 10/10 [==============================] - 7s 677ms/step - g_loss: 0.6878 - d_loss: 0.6929
# Epoch 133/1500
# 10/10 [==============================] - 7s 733ms/step - g_loss: 0.7141 - d_loss: 0.7005
# Epoch 134/1500
# 10/10 [==============================] - 7s 667ms/step - g_loss: 0.7252 - d_loss: 0.7013
# Epoch 135/1500
# 10/10 [==============================] - 7s 688ms/step - g_loss: 0.7178 - d_loss: 0.6973
# Epoch 136/1500
# 10/10 [==============================] - 7s 688ms/step - g_loss: 0.7109 - d_loss: 0.6966
# Epoch 137/1500
# 10/10 [==============================] - 8s 746ms/step - g_loss: 0.7021 - d_loss: 0.6951
# Epoch 138/1500
# 10/10 [==============================] - 7s 723ms/step - g_loss: 0.6920 - d_loss: 0.6931
# Epoch 139/1500
# 10/10 [==============================] - 7s 693ms/step - g_loss: 0.6838 - d_loss: 0.6936
# Epoch 140/1500
# 10/10 [==============================] - 7s 723ms/step - g_loss: 0.6847 - d_loss: 0.6967
# Epoch 141/1500
# 10/10 [==============================] - 7s 684ms/step - g_loss: 0.6906 - d_loss: 0.6999
# Epoch 142/1500
# 10/10 [==============================] - 7s 712ms/step - g_loss: 0.7048 - d_loss: 0.7024
# Epoch 143/1500
# 10/10 [==============================] - 7s 719ms/step - g_loss: 0.7186 - d_loss: 0.7017
# Epoch 144/1500
# 10/10 [==============================] - 7s 700ms/step - g_loss: 0.7222 - d_loss: 0.6982
# Epoch 145/1500
# 10/10 [==============================] - 7s 728ms/step - g_loss: 0.7012 - d_loss: 0.6946
# Epoch 146/1500
# 10/10 [==============================] - 7s 726ms/step - g_loss: 0.6762 - d_loss: 0.6919
# Epoch 147/1500
# 10/10 [==============================] - 7s 692ms/step - g_loss: 0.6616 - d_loss: 0.6873
# Epoch 148/1500
# 10/10 [==============================] - 7s 697ms/step - g_loss: 0.6609 - d_loss: 0.6867
# Epoch 149/1500
# 10/10 [==============================] - 7s 734ms/step - g_loss: 0.6863 - d_loss: 0.6851
# Epoch 150/1500
# 10/10 [==============================] - 7s 682ms/step - g_loss: 0.7019 - d_loss: 0.6823
# Epoch 151/1500
# 10/10 [==============================] - 7s 736ms/step - g_loss: 0.7007 - d_loss: 0.6851
# Epoch 152/1500
# 10/10 [==============================] - 7s 690ms/step - g_loss: 0.6983 - d_loss: 0.6859
# Epoch 153/1500
# 10/10 [==============================] - 7s 688ms/step - g_loss: 0.7015 - d_loss: 0.6868
# Epoch 154/1500
# 10/10 [==============================] - 7s 697ms/step - g_loss: 0.7078 - d_loss: 0.6865
# Epoch 155/1500
# 10/10 [==============================] - 7s 734ms/step - g_loss: 0.7037 - d_loss: 0.6898
# Epoch 156/1500
# 10/10 [==============================] - 7s 690ms/step - g_loss: 0.6841 - d_loss: 0.6917
# Epoch 157/1500
# 10/10 [==============================] - 7s 713ms/step - g_loss: 0.6599 - d_loss: 0.6956
# Epoch 158/1500
# 10/10 [==============================] - 7s 709ms/step - g_loss: 0.6557 - d_loss: 0.6976
# Epoch 159/1500
# 10/10 [==============================] - 7s 684ms/step - g_loss: 0.6694 - d_loss: 0.6995
# Epoch 160/1500
# 10/10 [==============================] - 7s 701ms/step - g_loss: 0.6951 - d_loss: 0.6999
# Epoch 161/1500
# 10/10 [==============================] - 7s 693ms/step - g_loss: 0.7124 - d_loss: 0.6971
# Epoch 162/1500
# 10/10 [==============================] - 7s 687ms/step - g_loss: 0.7158 - d_loss: 0.6944
# Epoch 163/1500
# 10/10 [==============================] - 7s 680ms/step - g_loss: 0.7130 - d_loss: 0.6889
# Epoch 164/1500
# 10/10 [==============================] - 7s 717ms/step - g_loss: 0.7097 - d_loss: 0.6881
# Epoch 165/1500
# 10/10 [==============================] - 7s 673ms/step - g_loss: 0.7144 - d_loss: 0.6843
# Epoch 166/1500
# 10/10 [==============================] - 7s 700ms/step - g_loss: 0.7119 - d_loss: 0.6856
# Epoch 167/1500
# 10/10 [==============================] - 7s 713ms/step - g_loss: 0.7130 - d_loss: 0.6871
# Epoch 168/1500
# 10/10 [==============================] - 7s 675ms/step - g_loss: 0.7301 - d_loss: 0.6906
# Epoch 169/1500
# 10/10 [==============================] - 7s 714ms/step - g_loss: 0.7498 - d_loss: 0.6925
# Epoch 170/1500
# 10/10 [==============================] - 7s 666ms/step - g_loss: 0.7494 - d_loss: 0.6903
# Epoch 171/1500
# 10/10 [==============================] - 7s 706ms/step - g_loss: 0.7308 - d_loss: 0.6916
# Epoch 172/1500
# 10/10 [==============================] - 7s 694ms/step - g_loss: 0.7072 - d_loss: 0.6943
# Epoch 173/1500
# 10/10 [==============================] - 7s 709ms/step - g_loss: 0.6972 - d_loss: 0.6936
# Epoch 174/1500
# 10/10 [==============================] - 7s 719ms/step - g_loss: 0.6800 - d_loss: 0.6911
# Epoch 175/1500
# 10/10 [==============================] - 7s 675ms/step - g_loss: 0.6727 - d_loss: 0.6872
# Epoch 176/1500
# 10/10 [==============================] - 7s 710ms/step - g_loss: 0.6802 - d_loss: 0.6829
# Epoch 177/1500
# 10/10 [==============================] - 7s 679ms/step - g_loss: 0.6884 - d_loss: 0.6876
# Epoch 178/1500
# 10/10 [==============================] - 7s 715ms/step - g_loss: 0.6896 - d_loss: 0.6941
# Epoch 179/1500
# 10/10 [==============================] - 7s 677ms/step - g_loss: 0.6880 - d_loss: 0.7049
# Epoch 180/1500
# 10/10 [==============================] - 7s 702ms/step - g_loss: 0.6800 - d_loss: 0.7095
# Epoch 181/1500
# 10/10 [==============================] - 7s 647ms/step - g_loss: 0.6674 - d_loss: 0.7105
# Epoch 182/1500
# 10/10 [==============================] - 7s 664ms/step - g_loss: 0.6636 - d_loss: 0.7046
# Epoch 183/1500
# 10/10 [==============================] - 7s 715ms/step - g_loss: 0.6832 - d_loss: 0.6968
# Epoch 184/1500
# 10/10 [==============================] - 7s 692ms/step - g_loss: 0.7188 - d_loss: 0.6865
# Epoch 185/1500
# 10/10 [==============================] - 7s 701ms/step - g_loss: 0.7220 - d_loss: 0.6816
# Epoch 186/1500
# 10/10 [==============================] - 7s 712ms/step - g_loss: 0.6915 - d_loss: 0.6830
# Epoch 187/1500
# 10/10 [==============================] - 7s 742ms/step - g_loss: 0.6689 - d_loss: 0.6788
# Epoch 188/1500
# 10/10 [==============================] - 7s 685ms/step - g_loss: 0.6672 - d_loss: 0.6809
# Epoch 189/1500
# 10/10 [==============================] - 7s 692ms/step - g_loss: 0.6871 - d_loss: 0.6867
# Epoch 190/1500
# 10/10 [==============================] - 7s 689ms/step - g_loss: 0.7234 - d_loss: 0.6894
# Epoch 191/1500
# 10/10 [==============================] - 7s 657ms/step - g_loss: 0.7490 - d_loss: 0.6918
# Epoch 192/1500
# 10/10 [==============================] - 7s 677ms/step - g_loss: 0.7381 - d_loss: 0.6932
# Epoch 193/1500
# 10/10 [==============================] - 7s 693ms/step - g_loss: 0.7056 - d_loss: 0.6993
# Epoch 194/1500
# 10/10 [==============================] - 7s 698ms/step - g_loss: 0.6884 - d_loss: 0.7071
# Epoch 195/1500
# 10/10 [==============================] - 7s 730ms/step - g_loss: 0.6791 - d_loss: 0.7104
# Epoch 196/1500
# 10/10 [==============================] - 7s 721ms/step - g_loss: 0.6789 - d_loss: 0.7138
# Epoch 197/1500
# 10/10 [==============================] - 7s 699ms/step - g_loss: 0.6869 - d_loss: 0.7096
# Epoch 198/1500
# 10/10 [==============================] - 7s 723ms/step - g_loss: 0.7062 - d_loss: 0.7035
# Epoch 199/1500
# 10/10 [==============================] - 7s 718ms/step - g_loss: 0.7320 - d_loss: 0.6969
# Epoch 200/1500
# 10/10 [==============================] - 7s 681ms/step - g_loss: 0.7247 - d_loss: 0.6923
# Epoch 201/1500
# 10/10 [==============================] - 7s 713ms/step - g_loss: 0.6906 - d_loss: 0.6894
# Epoch 202/1500
# 10/10 [==============================] - 7s 709ms/step - g_loss: 0.6686 - d_loss: 0.6866
# Epoch 203/1500
# 10/10 [==============================] - 8s 757ms/step - g_loss: 0.6801 - d_loss: 0.6840
# Epoch 204/1500
# 10/10 [==============================] - 7s 714ms/step - g_loss: 0.7058 - d_loss: 0.6830
# Epoch 205/1500
# 10/10 [==============================] - 7s 733ms/step - g_loss: 0.7279 - d_loss: 0.6868
# Epoch 206/1500
# 10/10 [==============================] - 7s 728ms/step - g_loss: 0.7453 - d_loss: 0.6868
# Epoch 207/1500
# 10/10 [==============================] - 7s 722ms/step - g_loss: 0.7598 - d_loss: 0.6843
# Epoch 208/1500
# 10/10 [==============================] - 7s 703ms/step - g_loss: 0.7323 - d_loss: 0.6902
# Epoch 209/1500
# 10/10 [==============================] - 7s 680ms/step - g_loss: 0.6818 - d_loss: 0.6973
# Epoch 210/1500
# 10/10 [==============================] - 7s 687ms/step - g_loss: 0.6541 - d_loss: 0.6941
# Epoch 211/1500
# 10/10 [==============================] - 7s 681ms/step - g_loss: 0.6478 - d_loss: 0.6919
# Epoch 212/1500
# 10/10 [==============================] - 7s 716ms/step - g_loss: 0.6851 - d_loss: 0.6928
# Epoch 213/1500
# 10/10 [==============================] - 7s 667ms/step - g_loss: 0.7445 - d_loss: 0.6900
# Epoch 214/1500
# 10/10 [==============================] - 7s 703ms/step - g_loss: 0.7523 - d_loss: 0.6897
# Epoch 215/1500
# 10/10 [==============================] - 7s 685ms/step - g_loss: 0.7223 - d_loss: 0.6980
# Epoch 216/1500
# 10/10 [==============================] - 7s 677ms/step - g_loss: 0.6970 - d_loss: 0.7006
# Epoch 217/1500
# 10/10 [==============================] - 7s 694ms/step - g_loss: 0.6703 - d_loss: 0.6996
# Epoch 218/1500
# 10/10 [==============================] - 7s 698ms/step - g_loss: 0.6597 - d_loss: 0.6933
# Epoch 219/1500
# 10/10 [==============================] - 7s 717ms/step - g_loss: 0.6724 - d_loss: 0.6917
# Epoch 220/1500
# 10/10 [==============================] - 7s 697ms/step - g_loss: 0.6966 - d_loss: 0.6900
# Epoch 221/1500
# 10/10 [==============================] - 7s 727ms/step - g_loss: 0.7239 - d_loss: 0.6880
# Epoch 222/1500
# 10/10 [==============================] - 7s 711ms/step - g_loss: 0.7376 - d_loss: 0.6886
# Epoch 223/1500
# 10/10 [==============================] - 7s 722ms/step - g_loss: 0.7220 - d_loss: 0.6949
# Epoch 224/1500
# 10/10 [==============================] - 7s 698ms/step - g_loss: 0.6893 - d_loss: 0.7022
# Epoch 225/1500
# 10/10 [==============================] - 7s 692ms/step - g_loss: 0.6691 - d_loss: 0.7004
# Epoch 226/1500
# 10/10 [==============================] - 7s 721ms/step - g_loss: 0.6664 - d_loss: 0.6930
# Epoch 227/1500
# 10/10 [==============================] - 7s 703ms/step - g_loss: 0.6894 - d_loss: 0.6884
# Epoch 228/1500
# 10/10 [==============================] - 7s 722ms/step - g_loss: 0.7181 - d_loss: 0.6880
# Epoch 229/1500
# 10/10 [==============================] - 7s 686ms/step - g_loss: 0.7213 - d_loss: 0.6878
# Epoch 230/1500
# 10/10 [==============================] - 7s 732ms/step - g_loss: 0.7069 - d_loss: 0.6898
# Epoch 231/1500
# 10/10 [==============================] - 7s 674ms/step - g_loss: 0.6972 - d_loss: 0.6929
# Epoch 232/1500
# 10/10 [==============================] - 7s 673ms/step - g_loss: 0.7067 - d_loss: 0.6933
# Epoch 233/1500
# 10/10 [==============================] - 7s 682ms/step - g_loss: 0.7240 - d_loss: 0.6909
# Epoch 234/1500
# 10/10 [==============================] - 7s 688ms/step - g_loss: 0.7199 - d_loss: 0.6918
# Epoch 235/1500
# 10/10 [==============================] - 7s 719ms/step - g_loss: 0.6974 - d_loss: 0.6933
# Epoch 236/1500
# 10/10 [==============================] - 7s 695ms/step - g_loss: 0.6784 - d_loss: 0.6920
# Epoch 237/1500
# 10/10 [==============================] - 7s 688ms/step - g_loss: 0.6731 - d_loss: 0.6910
# Epoch 238/1500
# 10/10 [==============================] - 7s 686ms/step - g_loss: 0.7097 - d_loss: 0.6878
# Epoch 239/1500
# 10/10 [==============================] - 7s 714ms/step - g_loss: 0.7439 - d_loss: 0.6830
# Epoch 240/1500
# 10/10 [==============================] - 7s 709ms/step - g_loss: 0.7243 - d_loss: 0.6857
# Epoch 241/1500
# 10/10 [==============================] - 7s 692ms/step - g_loss: 0.6904 - d_loss: 0.6852
# Epoch 242/1500
# 10/10 [==============================] - 7s 685ms/step - g_loss: 0.6707 - d_loss: 0.6829
# Epoch 243/1500
# 10/10 [==============================] - 7s 687ms/step - g_loss: 0.6768 - d_loss: 0.6794
# Epoch 244/1500
# 10/10 [==============================] - 7s 702ms/step - g_loss: 0.7083 - d_loss: 0.6759
# Epoch 245/1500
# 10/10 [==============================] - 7s 669ms/step - g_loss: 0.7381 - d_loss: 0.6808
# Epoch 246/1500
# 10/10 [==============================] - 7s 715ms/step - g_loss: 0.7476 - d_loss: 0.6862
# Epoch 247/1500
# 10/10 [==============================] - 7s 730ms/step - g_loss: 0.7418 - d_loss: 0.6912
# Epoch 248/1500
# 10/10 [==============================] - 7s 718ms/step - g_loss: 0.7232 - d_loss: 0.6957
# Epoch 249/1500
# 10/10 [==============================] - 7s 667ms/step - g_loss: 0.6952 - d_loss: 0.6971
# Epoch 250/1500
# 10/10 [==============================] - 7s 687ms/step - g_loss: 0.6718 - d_loss: 0.6947
# Epoch 251/1500
# 10/10 [==============================] - 7s 679ms/step - g_loss: 0.6600 - d_loss: 0.6924
# Epoch 252/1500
# 10/10 [==============================] - 7s 722ms/step - g_loss: 0.6786 - d_loss: 0.6879
# Epoch 253/1500
# 10/10 [==============================] - 7s 719ms/step - g_loss: 0.7086 - d_loss: 0.6857
# Epoch 254/1500
# 10/10 [==============================] - 7s 659ms/step - g_loss: 0.7176 - d_loss: 0.6848
# Epoch 255/1500
# 10/10 [==============================] - 7s 696ms/step - g_loss: 0.7130 - d_loss: 0.6817
# Epoch 256/1500
# 10/10 [==============================] - 7s 726ms/step - g_loss: 0.7153 - d_loss: 0.6778
# Epoch 257/1500
# 10/10 [==============================] - 7s 699ms/step - g_loss: 0.7243 - d_loss: 0.6788
# Epoch 258/1500
# 10/10 [==============================] - 7s 695ms/step - g_loss: 0.7138 - d_loss: 0.6900
# Epoch 259/1500
# 10/10 [==============================] - 7s 705ms/step - g_loss: 0.7197 - d_loss: 0.6930
# Epoch 260/1500
# 10/10 [==============================] - 8s 758ms/step - g_loss: 0.7058 - d_loss: 0.6936
# Epoch 261/1500
# 10/10 [==============================] - 7s 697ms/step - g_loss: 0.6924 - d_loss: 0.6944
# Epoch 262/1500
# 10/10 [==============================] - 7s 712ms/step - g_loss: 0.7029 - d_loss: 0.6912
# Epoch 263/1500
# 10/10 [==============================] - 7s 696ms/step - g_loss: 0.7360 - d_loss: 0.6816
# Epoch 264/1500
# 10/10 [==============================] - 7s 697ms/step - g_loss: 0.7373 - d_loss: 0.6808
# Epoch 265/1500
# 10/10 [==============================] - 7s 670ms/step - g_loss: 0.6858 - d_loss: 0.6900
# Epoch 266/1500
# 10/10 [==============================] - 7s 677ms/step - g_loss: 0.6499 - d_loss: 0.6940
# Epoch 267/1500
# 10/10 [==============================] - 7s 655ms/step - g_loss: 0.6402 - d_loss: 0.6902
# Epoch 268/1500
# 10/10 [==============================] - 7s 717ms/step - g_loss: 0.6808 - d_loss: 0.6897
# Epoch 269/1500
# 10/10 [==============================] - 7s 688ms/step - g_loss: 0.7435 - d_loss: 0.6905
# Epoch 270/1500
# 10/10 [==============================] - 7s 673ms/step - g_loss: 0.7461 - d_loss: 0.6929
# Epoch 271/1500
# 10/10 [==============================] - 7s 691ms/step - g_loss: 0.7145 - d_loss: 0.6906
# Epoch 272/1500
# 10/10 [==============================] - 7s 675ms/step - g_loss: 0.6917 - d_loss: 0.6884
# Epoch 273/1500
# 10/10 [==============================] - 7s 695ms/step - g_loss: 0.6872 - d_loss: 0.6841
# Epoch 274/1500
# 10/10 [==============================] - 7s 695ms/step - g_loss: 0.6922 - d_loss: 0.6790
# Epoch 275/1500
# 10/10 [==============================] - 7s 691ms/step - g_loss: 0.7296 - d_loss: 0.6644
# Epoch 276/1500
# 10/10 [==============================] - 7s 685ms/step - g_loss: 0.7410 - d_loss: 0.6635
# Epoch 277/1500
# 10/10 [==============================] - 7s 709ms/step - g_loss: 0.6778 - d_loss: 0.7010
# Epoch 278/1500
# 10/10 [==============================] - 7s 709ms/step - g_loss: 0.6722 - d_loss: 0.7147
# Epoch 279/1500
# 10/10 [==============================] - 7s 692ms/step - g_loss: 0.7087 - d_loss: 0.7209
# Epoch 280/1500
# 10/10 [==============================] - 7s 701ms/step - g_loss: 0.7754 - d_loss: 0.7083
# Epoch 281/1500
# 10/10 [==============================] - 7s 706ms/step - g_loss: 0.7783 - d_loss: 0.6941
# Epoch 282/1500
# 10/10 [==============================] - 7s 706ms/step - g_loss: 0.7096 - d_loss: 0.6898
# Epoch 283/1500
# 10/10 [==============================] - 7s 713ms/step - g_loss: 0.6642 - d_loss: 0.6838
# Epoch 284/1500
# 10/10 [==============================] - 7s 711ms/step - g_loss: 0.6599 - d_loss: 0.6771
# Epoch 285/1500
# 10/10 [==============================] - 7s 681ms/step - g_loss: 0.6674 - d_loss: 0.6799
# Epoch 286/1500
# 10/10 [==============================] - 7s 699ms/step - g_loss: 0.6830 - d_loss: 0.6928
# Epoch 287/1500
# 10/10 [==============================] - 7s 701ms/step - g_loss: 0.7289 - d_loss: 0.6937
# Epoch 288/1500
# 10/10 [==============================] - 7s 689ms/step - g_loss: 0.7532 - d_loss: 0.6886
# Epoch 289/1500
# 10/10 [==============================] - 7s 693ms/step - g_loss: 0.7501 - d_loss: 0.6792
# Epoch 290/1500
# 10/10 [==============================] - 7s 673ms/step - g_loss: 0.7242 - d_loss: 0.6750
# Epoch 291/1500
# 10/10 [==============================] - 7s 723ms/step - g_loss: 0.7020 - d_loss: 0.6694
# Epoch 292/1500
# 10/10 [==============================] - 7s 687ms/step - g_loss: 0.6644 - d_loss: 0.6839
# Epoch 293/1500
# 10/10 [==============================] - 7s 692ms/step - g_loss: 0.6655 - d_loss: 0.6987
# Epoch 294/1500
# 10/10 [==============================] - 7s 682ms/step - g_loss: 0.6836 - d_loss: 0.7050
# Epoch 295/1500
# 10/10 [==============================] - 7s 658ms/step - g_loss: 0.7144 - d_loss: 0.7004
# Epoch 296/1500
# 10/10 [==============================] - 7s 694ms/step - g_loss: 0.7394 - d_loss: 0.6919
# Epoch 297/1500
# 10/10 [==============================] - 7s 670ms/step - g_loss: 0.7284 - d_loss: 0.6805
# Epoch 298/1500
# 10/10 [==============================] - 7s 692ms/step - g_loss: 0.7002 - d_loss: 0.6792
# Epoch 299/1500
# 10/10 [==============================] - 7s 663ms/step - g_loss: 0.6865 - d_loss: 0.6847
# Epoch 300/1500
# 10/10 [==============================] - 7s 673ms/step - g_loss: 0.7010 - d_loss: 0.6953
# Epoch 301/1500
# 10/10 [==============================] - 7s 720ms/step - g_loss: 0.7368 - d_loss: 0.7028
# Epoch 302/1500
# 10/10 [==============================] - 7s 680ms/step - g_loss: 0.7552 - d_loss: 0.7039
# Epoch 303/1500
# 10/10 [==============================] - 7s 709ms/step - g_loss: 0.7501 - d_loss: 0.6925
# Epoch 304/1500
# 10/10 [==============================] - 7s 668ms/step - g_loss: 0.7169 - d_loss: 0.6805
# Epoch 305/1500
# 10/10 [==============================] - 8s 746ms/step - g_loss: 0.6808 - d_loss: 0.6697
# Epoch 306/1500
# 10/10 [==============================] - 7s 700ms/step - g_loss: 0.6516 - d_loss: 0.6779
# Epoch 307/1500
# 10/10 [==============================] - 7s 712ms/step - g_loss: 0.6753 - d_loss: 0.6789
# Epoch 308/1500
# 10/10 [==============================] - 7s 688ms/step - g_loss: 0.6965 - d_loss: 0.6876
# Epoch 309/1500
# 10/10 [==============================] - 7s 701ms/step - g_loss: 0.7106 - d_loss: 0.6931
# Epoch 310/1500
# 10/10 [==============================] - 7s 676ms/step - g_loss: 0.7053 - d_loss: 0.6952
# Epoch 311/1500
# 10/10 [==============================] - 7s 702ms/step - g_loss: 0.7152 - d_loss: 0.6806
# Epoch 312/1500
# 10/10 [==============================] - 7s 703ms/step - g_loss: 0.7084 - d_loss: 0.6787
# Epoch 313/1500
# 10/10 [==============================] - 7s 668ms/step - g_loss: 0.6473 - d_loss: 0.7211
# Epoch 314/1500
# 10/10 [==============================] - 7s 673ms/step - g_loss: 0.6753 - d_loss: 0.7275
# Epoch 315/1500
# 10/10 [==============================] - 7s 647ms/step - g_loss: 0.7192 - d_loss: 0.7115
# Epoch 316/1500
# 10/10 [==============================] - 7s 697ms/step - g_loss: 0.7392 - d_loss: 0.6924
# Epoch 317/1500
# 10/10 [==============================] - 7s 676ms/step - g_loss: 0.7498 - d_loss: 0.6794
# Epoch 318/1500
# 10/10 [==============================] - 7s 662ms/step - g_loss: 0.7549 - d_loss: 0.6701
# Epoch 319/1500
# 10/10 [==============================] - 7s 693ms/step - g_loss: 0.6850 - d_loss: 0.6997
# Epoch 320/1500
# 10/10 [==============================] - 7s 697ms/step - g_loss: 0.7075 - d_loss: 0.6937
# Epoch 321/1500
# 10/10 [==============================] - 7s 712ms/step - g_loss: 0.7185 - d_loss: 0.6899
# Epoch 322/1500
# 10/10 [==============================] - 7s 683ms/step - g_loss: 0.7153 - d_loss: 0.6929
# Epoch 323/1500
# 10/10 [==============================] - 7s 705ms/step - g_loss: 0.7072 - d_loss: 0.7001
# Epoch 324/1500
# 10/10 [==============================] - 7s 672ms/step - g_loss: 0.7064 - d_loss: 0.7044
# Epoch 325/1500
# 10/10 [==============================] - 7s 655ms/step - g_loss: 0.7276 - d_loss: 0.6983
# Epoch 326/1500
# 10/10 [==============================] - 7s 688ms/step - g_loss: 0.7283 - d_loss: 0.6961
# Epoch 327/1500
# 10/10 [==============================] - 7s 668ms/step - g_loss: 0.7049 - d_loss: 0.6899
# Epoch 328/1500
# 10/10 [==============================] - 7s 704ms/step - g_loss: 0.6733 - d_loss: 0.6836
# Epoch 329/1500
# 10/10 [==============================] - 7s 674ms/step - g_loss: 0.6564 - d_loss: 0.6793
# Epoch 330/1500
# 10/10 [==============================] - 7s 699ms/step - g_loss: 0.6636 - d_loss: 0.6786
# Epoch 331/1500
# 10/10 [==============================] - 7s 675ms/step - g_loss: 0.6785 - d_loss: 0.6837
# Epoch 332/1500
# 10/10 [==============================] - 7s 720ms/step - g_loss: 0.7015 - d_loss: 0.6867
# Epoch 333/1500
# 10/10 [==============================] - 7s 713ms/step - g_loss: 0.7330 - d_loss: 0.6855
# Epoch 334/1500
# 10/10 [==============================] - 7s 704ms/step - g_loss: 0.7425 - d_loss: 0.6853
# Epoch 335/1500
# 10/10 [==============================] - 7s 701ms/step - g_loss: 0.7244 - d_loss: 0.6837
# Epoch 336/1500
# 10/10 [==============================] - 7s 703ms/step - g_loss: 0.7021 - d_loss: 0.6820
# Epoch 337/1500
# 10/10 [==============================] - 7s 701ms/step - g_loss: 0.6756 - d_loss: 0.6879
# Epoch 338/1500
# 10/10 [==============================] - 7s 676ms/step - g_loss: 0.6566 - d_loss: 0.7145
# Epoch 339/1500
# 10/10 [==============================] - 7s 666ms/step - g_loss: 0.7109 - d_loss: 0.7111
# Epoch 340/1500
# 10/10 [==============================] - 7s 677ms/step - g_loss: 0.7299 - d_loss: 0.7120
# Epoch 341/1500
# 10/10 [==============================] - 7s 706ms/step - g_loss: 0.7466 - d_loss: 0.6933
# Epoch 342/1500
# 10/10 [==============================] - 7s 689ms/step - g_loss: 0.7555 - d_loss: 0.6682
# Epoch 343/1500
# 10/10 [==============================] - 7s 678ms/step - g_loss: 0.6892 - d_loss: 0.6900
# Epoch 344/1500
# 10/10 [==============================] - 7s 706ms/step - g_loss: 0.6321 - d_loss: 0.7254
# Epoch 345/1500
# 10/10 [==============================] - 7s 693ms/step - g_loss: 0.6608 - d_loss: 0.7194
# Epoch 346/1500
# 10/10 [==============================] - 7s 704ms/step - g_loss: 0.7060 - d_loss: 0.6993
# Epoch 347/1500
# 10/10 [==============================] - 7s 702ms/step - g_loss: 0.7160 - d_loss: 0.6866
# Epoch 348/1500
# 10/10 [==============================] - 7s 713ms/step - g_loss: 0.6758 - d_loss: 0.7010
# Epoch 349/1500
# 10/10 [==============================] - 7s 713ms/step - g_loss: 0.6622 - d_loss: 0.7181
# Epoch 350/1500
# 10/10 [==============================] - 7s 698ms/step - g_loss: 0.7120 - d_loss: 0.7065
# Epoch 351/1500
# 10/10 [==============================] - 7s 725ms/step - g_loss: 0.7386 - d_loss: 0.7028
# Epoch 352/1500
# 10/10 [==============================] - 7s 664ms/step - g_loss: 0.7312 - d_loss: 0.7083
# Epoch 353/1500
# 10/10 [==============================] - 7s 710ms/step - g_loss: 0.7268 - d_loss: 0.7055
# Epoch 354/1500
# 10/10 [==============================] - 7s 672ms/step - g_loss: 0.7344 - d_loss: 0.6881
# Epoch 355/1500
# 10/10 [==============================] - 7s 719ms/step - g_loss: 0.7054 - d_loss: 0.6866
# Epoch 356/1500
# 10/10 [==============================] - 7s 697ms/step - g_loss: 0.6413 - d_loss: 0.7137
# Epoch 357/1500
# 10/10 [==============================] - 7s 702ms/step - g_loss: 0.6893 - d_loss: 0.7003
# Epoch 358/1500
# 10/10 [==============================] - 7s 701ms/step - g_loss: 0.7216 - d_loss: 0.6948
# Epoch 359/1500
# 10/10 [==============================] - 7s 686ms/step - g_loss: 0.7445 - d_loss: 0.6922
# Epoch 360/1500
# 10/10 [==============================] - 7s 672ms/step - g_loss: 0.7311 - d_loss: 0.6978
# Epoch 361/1500
# 10/10 [==============================] - 7s 694ms/step - g_loss: 0.6945 - d_loss: 0.7122
# Epoch 362/1500
# 10/10 [==============================] - 7s 698ms/step - g_loss: 0.6869 - d_loss: 0.7129
# Epoch 363/1500
# 10/10 [==============================] - 7s 693ms/step - g_loss: 0.7047 - d_loss: 0.6975
# Epoch 364/1500
# 10/10 [==============================] - 7s 699ms/step - g_loss: 0.7150 - d_loss: 0.6796
# Epoch 365/1500
# 10/10 [==============================] - 7s 697ms/step - g_loss: 0.6833 - d_loss: 0.6839
# Epoch 366/1500
# 10/10 [==============================] - 7s 680ms/step - g_loss: 0.6391 - d_loss: 0.7155
# Epoch 367/1500
# 10/10 [==============================] - 7s 698ms/step - g_loss: 0.7046 - d_loss: 0.7119
# Epoch 368/1500
# 10/10 [==============================] - 7s 670ms/step - g_loss: 0.7552 - d_loss: 0.7007
# Epoch 369/1500
# 10/10 [==============================] - 7s 700ms/step - g_loss: 0.7548 - d_loss: 0.6949
# Epoch 370/1500
# 10/10 [==============================] - 7s 680ms/step - g_loss: 0.7240 - d_loss: 0.6937
# Epoch 371/1500
# 10/10 [==============================] - 7s 706ms/step - g_loss: 0.6810 - d_loss: 0.6960
# Epoch 372/1500
# 10/10 [==============================] - 7s 690ms/step - g_loss: 0.6443 - d_loss: 0.7051
# Epoch 373/1500
# 10/10 [==============================] - 7s 700ms/step - g_loss: 0.6557 - d_loss: 0.6959
# Epoch 374/1500
# 10/10 [==============================] - 7s 696ms/step - g_loss: 0.6891 - d_loss: 0.6788
# Epoch 375/1500
# 10/10 [==============================] - 7s 686ms/step - g_loss: 0.7197 - d_loss: 0.6663
# Epoch 376/1500
# 10/10 [==============================] - 7s 690ms/step - g_loss: 0.7196 - d_loss: 0.6673
# Epoch 377/1500
# 10/10 [==============================] - 7s 649ms/step - g_loss: 0.6514 - d_loss: 0.7166
# Epoch 378/1500
# 10/10 [==============================] - 7s 697ms/step - g_loss: 0.6984 - d_loss: 0.7182
# Epoch 379/1500
# 10/10 [==============================] - 7s 671ms/step - g_loss: 0.7372 - d_loss: 0.7131
# Epoch 380/1500
# 10/10 [==============================] - 7s 696ms/step - g_loss: 0.7505 - d_loss: 0.7036
# Epoch 381/1500
# 10/10 [==============================] - 7s 686ms/step - g_loss: 0.7274 - d_loss: 0.6998
# Epoch 382/1500
# 10/10 [==============================] - 7s 679ms/step - g_loss: 0.6902 - d_loss: 0.6997
# Epoch 383/1500
# 10/10 [==============================] - 7s 712ms/step - g_loss: 0.6675 - d_loss: 0.6974
# Epoch 384/1500
# 10/10 [==============================] - 7s 696ms/step - g_loss: 0.6627 - d_loss: 0.6972
# Epoch 385/1500
# 10/10 [==============================] - 7s 728ms/step - g_loss: 0.6744 - d_loss: 0.6951
# Epoch 386/1500
# 10/10 [==============================] - 7s 712ms/step - g_loss: 0.6918 - d_loss: 0.6902
# Epoch 387/1500
# 10/10 [==============================] - 7s 721ms/step - g_loss: 0.6969 - d_loss: 0.6881
# Epoch 388/1500
# 10/10 [==============================] - 7s 678ms/step - g_loss: 0.6870 - d_loss: 0.6925
# Epoch 389/1500
# 10/10 [==============================] - 7s 713ms/step - g_loss: 0.6718 - d_loss: 0.6991
# Epoch 390/1500
# 10/10 [==============================] - 7s 698ms/step - g_loss: 0.6790 - d_loss: 0.6968
# Epoch 391/1500
# 10/10 [==============================] - 7s 671ms/step - g_loss: 0.6971 - d_loss: 0.6849
# Epoch 392/1500
# 10/10 [==============================] - 7s 699ms/step - g_loss: 0.7112 - d_loss: 0.6758
# Epoch 393/1500
# 10/10 [==============================] - 7s 677ms/step - g_loss: 0.7125 - d_loss: 0.6691
# Epoch 394/1500
# 10/10 [==============================] - 7s 716ms/step - g_loss: 0.7050 - d_loss: 0.6705
# Epoch 395/1500
# 10/10 [==============================] - 7s 694ms/step - g_loss: 0.6573 - d_loss: 0.7041
# Epoch 396/1500
# 10/10 [==============================] - 7s 722ms/step - g_loss: 0.5955 - d_loss: 0.7616
# Epoch 397/1500
# 10/10 [==============================] - 7s 679ms/step - g_loss: 0.6850 - d_loss: 0.7387
# Epoch 398/1500
# 10/10 [==============================] - 7s 692ms/step - g_loss: 0.7709 - d_loss: 0.7110
# Epoch 399/1500
# 10/10 [==============================] - 7s 686ms/step - g_loss: 0.8215 - d_loss: 0.6805
# Epoch 400/1500
# 10/10 [==============================] - 7s 683ms/step - g_loss: 0.8104 - d_loss: 0.6623
# Epoch 401/1500
# 10/10 [==============================] - 7s 690ms/step - g_loss: 0.7622 - d_loss: 0.6648
# Epoch 402/1500
# 10/10 [==============================] - 7s 674ms/step - g_loss: 0.7339 - d_loss: 0.6668
# Epoch 403/1500
# 10/10 [==============================] - 7s 724ms/step - g_loss: 0.7085 - d_loss: 0.6713
# Epoch 404/1500
# 10/10 [==============================] - 7s 698ms/step - g_loss: 0.6874 - d_loss: 0.6834
# Epoch 405/1500
# 10/10 [==============================] - 7s 690ms/step - g_loss: 0.6789 - d_loss: 0.6955
# Epoch 406/1500
# 10/10 [==============================] - 7s 694ms/step - g_loss: 0.6760 - d_loss: 0.6964
# Epoch 407/1500
# 10/10 [==============================] - 7s 696ms/step - g_loss: 0.6726 - d_loss: 0.7026
# Epoch 408/1500
# 10/10 [==============================] - 7s 678ms/step - g_loss: 0.6721 - d_loss: 0.7042
# Epoch 409/1500
# 10/10 [==============================] - 7s 686ms/step - g_loss: 0.6749 - d_loss: 0.7040
# Epoch 410/1500
# 10/10 [==============================] - 7s 708ms/step - g_loss: 0.6801 - d_loss: 0.7004
# Epoch 411/1500
# 10/10 [==============================] - 7s 682ms/step - g_loss: 0.6883 - d_loss: 0.6964
# Epoch 412/1500
# 10/10 [==============================] - 7s 686ms/step - g_loss: 0.6961 - d_loss: 0.6906
# Epoch 413/1500
# 10/10 [==============================] - 7s 692ms/step - g_loss: 0.6999 - d_loss: 0.6837
# Epoch 414/1500
# 10/10 [==============================] - 7s 682ms/step - g_loss: 0.6996 - d_loss: 0.6828
# Epoch 415/1500
# 10/10 [==============================] - 7s 717ms/step - g_loss: 0.7069 - d_loss: 0.6786
# Epoch 416/1500
# 10/10 [==============================] - 7s 706ms/step - g_loss: 0.7180 - d_loss: 0.6760
# Epoch 417/1500
# 10/10 [==============================] - 7s 727ms/step - g_loss: 0.7241 - d_loss: 0.6741
# Epoch 418/1500
# 10/10 [==============================] - 7s 678ms/step - g_loss: 0.7251 - d_loss: 0.6724
# Epoch 419/1500
# 10/10 [==============================] - 7s 683ms/step - g_loss: 0.7127 - d_loss: 0.6783
# Epoch 420/1500
# 10/10 [==============================] - 7s 674ms/step - g_loss: 0.6975 - d_loss: 0.6848
# Epoch 421/1500
# 10/10 [==============================] - 7s 684ms/step - g_loss: 0.6926 - d_loss: 0.6910
# Epoch 422/1500
# 10/10 [==============================] - 7s 678ms/step - g_loss: 0.6973 - d_loss: 0.6936
# Epoch 423/1500
# 10/10 [==============================] - 7s 710ms/step - g_loss: 0.7096 - d_loss: 0.6927
# Epoch 424/1500
# 10/10 [==============================] - 7s 713ms/step - g_loss: 0.7117 - d_loss: 0.6917
# Epoch 425/1500
# 10/10 [==============================] - 7s 686ms/step - g_loss: 0.7048 - d_loss: 0.6923
# Epoch 426/1500
# 10/10 [==============================] - 7s 726ms/step - g_loss: 0.7029 - d_loss: 0.6918
# Epoch 427/1500
# 10/10 [==============================] - 7s 682ms/step - g_loss: 0.7063 - d_loss: 0.6902
# Epoch 428/1500
# 10/10 [==============================] - 7s 690ms/step - g_loss: 0.7080 - d_loss: 0.6918
# Epoch 429/1500
# 10/10 [==============================] - 7s 669ms/step - g_loss: 0.7075 - d_loss: 0.6902
# Epoch 430/1500
# 10/10 [==============================] - 7s 687ms/step - g_loss: 0.7021 - d_loss: 0.6889
# Epoch 431/1500
# 10/10 [==============================] - 7s 685ms/step - g_loss: 0.6962 - d_loss: 0.6882
# Epoch 432/1500
# 10/10 [==============================] - 7s 683ms/step - g_loss: 0.6918 - d_loss: 0.6850
# Epoch 433/1500
# 10/10 [==============================] - 7s 704ms/step - g_loss: 0.6883 - d_loss: 0.6847
# Epoch 434/1500
# 10/10 [==============================] - 7s 694ms/step - g_loss: 0.6871 - d_loss: 0.6841
# Epoch 435/1500
# 10/10 [==============================] - 7s 712ms/step - g_loss: 0.6969 - d_loss: 0.6812
# Epoch 436/1500
# 10/10 [==============================] - 7s 685ms/step - g_loss: 0.7187 - d_loss: 0.6766
# Epoch 437/1500
# 10/10 [==============================] - 7s 704ms/step - g_loss: 0.7303 - d_loss: 0.6722
# Epoch 438/1500
# 10/10 [==============================] - 7s 682ms/step - g_loss: 0.7182 - d_loss: 0.6805
# Epoch 439/1500
# 10/10 [==============================] - 7s 712ms/step - g_loss: 0.7333 - d_loss: 0.6788
# Epoch 440/1500
# 10/10 [==============================] - 7s 722ms/step - g_loss: 0.7375 - d_loss: 0.6759
# Epoch 441/1500
# 10/10 [==============================] - 7s 747ms/step - g_loss: 0.7218 - d_loss: 0.6775
# Epoch 442/1500
# 10/10 [==============================] - 7s 712ms/step - g_loss: 0.6822 - d_loss: 0.6870
# Epoch 443/1500
# 10/10 [==============================] - 7s 679ms/step - g_loss: 0.6624 - d_loss: 0.6878
# Epoch 444/1500
# 10/10 [==============================] - 7s 724ms/step - g_loss: 0.6618 - d_loss: 0.6804
# Epoch 445/1500
# 10/10 [==============================] - 7s 695ms/step - g_loss: 0.6712 - d_loss: 0.6713
# Epoch 446/1500
# 10/10 [==============================] - 7s 706ms/step - g_loss: 0.6925 - d_loss: 0.6628
# Epoch 447/1500
# 10/10 [==============================] - 7s 654ms/step - g_loss: 0.7108 - d_loss: 0.6566
# Epoch 448/1500
# 10/10 [==============================] - 7s 675ms/step - g_loss: 0.7076 - d_loss: 0.6611
# Epoch 449/1500
# 10/10 [==============================] - 7s 701ms/step - g_loss: 0.6991 - d_loss: 0.6785
# Epoch 450/1500
# 10/10 [==============================] - 7s 674ms/step - g_loss: 0.7216 - d_loss: 0.6889
# Epoch 451/1500
# 10/10 [==============================] - 7s 688ms/step - g_loss: 0.7517 - d_loss: 0.6893
# Epoch 452/1500
# 10/10 [==============================] - 7s 697ms/step - g_loss: 0.7757 - d_loss: 0.6906
# Epoch 453/1500
# 10/10 [==============================] - 7s 689ms/step - g_loss: 0.7801 - d_loss: 0.6892
# Epoch 454/1500
# 10/10 [==============================] - 7s 661ms/step - g_loss: 0.7668 - d_loss: 0.6852
# Epoch 455/1500
# 10/10 [==============================] - 7s 694ms/step - g_loss: 0.7552 - d_loss: 0.6776
# Epoch 456/1500
# 10/10 [==============================] - 7s 703ms/step - g_loss: 0.7330 - d_loss: 0.6718
# Epoch 457/1500
# 10/10 [==============================] - 7s 673ms/step - g_loss: 0.7085 - d_loss: 0.6668
# Epoch 458/1500
# 10/10 [==============================] - 7s 680ms/step - g_loss: 0.6943 - d_loss: 0.6670
# Epoch 459/1500
# 10/10 [==============================] - 7s 687ms/step - g_loss: 0.6853 - d_loss: 0.6702
# Epoch 460/1500
# 10/10 [==============================] - 7s 709ms/step - g_loss: 0.6761 - d_loss: 0.6773
# Epoch 461/1500
# 10/10 [==============================] - 7s 722ms/step - g_loss: 0.6752 - d_loss: 0.6861
# Epoch 462/1500
# 10/10 [==============================] - 7s 729ms/step - g_loss: 0.6817 - d_loss: 0.6877
# Epoch 463/1500
# ...
# Epoch 1349/1500
# 10/10 [==============================] - 7s 653ms/step - g_loss: 0.6881 - d_loss: 0.6651
# Epoch 1350/1500
# 10/10 [==============================] - 7s 677ms/step - g_loss: 0.6930 - d_loss: 0.6613
# Epoch 1351/1500
# 10/10 [==============================] - 7s 655ms/step - g_loss: 0.6968 - d_loss: 0.6541
# Epoch 1352/1500
# 10/10 [==============================] - 7s 662ms/step - g_loss: 0.7032 - d_loss: 0.6547
# Epoch 1353/1500
# 10/10 [==============================] - 7s 675ms/step - g_loss: 0.7082 - d_loss: 0.6518
# Epoch 1354/1500
# 10/10 [==============================] - 7s 708ms/step - g_loss: 0.7090 - d_loss: 0.6469
# Epoch 1355/1500
# 10/10 [==============================] - 7s 710ms/step - g_loss: 0.7104 - d_loss: 0.6450
# Epoch 1356/1500
# 10/10 [==============================] - 7s 683ms/step - g_loss: 0.7160 - d_loss: 0.6414
# Epoch 1357/1500
# 10/10 [==============================] - 7s 699ms/step - g_loss: 0.7190 - d_loss: 0.6381
# Epoch 1358/1500
# 10/10 [==============================] - 7s 683ms/step - g_loss: 0.7200 - d_loss: 0.6407
# Epoch 1359/1500
# 10/10 [==============================] - 7s 696ms/step - g_loss: 0.7231 - d_loss: 0.6386
# Epoch 1360/1500
# 10/10 [==============================] - 7s 693ms/step - g_loss: 0.7190 - d_loss: 0.6365
# Epoch 1361/1500
# 10/10 [==============================] - 7s 678ms/step - g_loss: 0.7162 - d_loss: 0.6351
# Epoch 1362/1500
# 10/10 [==============================] - 7s 698ms/step - g_loss: 0.7010 - d_loss: 0.6461
# Epoch 1363/1500
# 10/10 [==============================] - 7s 683ms/step - g_loss: 0.6597 - d_loss: 0.6641
# Epoch 1364/1500
# 10/10 [==============================] - 7s 700ms/step - g_loss: 0.6442 - d_loss: 0.6758
# Epoch 1365/1500
# 10/10 [==============================] - 7s 679ms/step - g_loss: 0.6395 - d_loss: 0.6842
# Epoch 1366/1500
# 10/10 [==============================] - 7s 691ms/step - g_loss: 0.6317 - d_loss: 0.6895
# Epoch 1367/1500
# 10/10 [==============================] - 7s 693ms/step - g_loss: 0.6325 - d_loss: 0.6894
# Epoch 1368/1500
# 10/10 [==============================] - 7s 693ms/step - g_loss: 0.6346 - d_loss: 0.6929
# Epoch 1369/1500
# 10/10 [==============================] - 7s 699ms/step - g_loss: 0.6366 - d_loss: 0.6940
# Epoch 1370/1500
# 10/10 [==============================] - 7s 689ms/step - g_loss: 0.6429 - d_loss: 0.6964
# Epoch 1371/1500
# 10/10 [==============================] - 7s 715ms/step - g_loss: 0.6442 - d_loss: 0.6947
# Epoch 1372/1500
# 10/10 [==============================] - 7s 681ms/step - g_loss: 0.6512 - d_loss: 0.6970
# Epoch 1373/1500
# 10/10 [==============================] - 7s 707ms/step - g_loss: 0.6544 - d_loss: 0.6978
# Epoch 1374/1500
# 10/10 [==============================] - 7s 691ms/step - g_loss: 0.6607 - d_loss: 0.6984
# Epoch 1375/1500
# 10/10 [==============================] - 7s 707ms/step - g_loss: 0.6648 - d_loss: 0.6973
# Epoch 1376/1500
# 10/10 [==============================] - 7s 699ms/step - g_loss: 0.6690 - d_loss: 0.6980
# Epoch 1377/1500
# 10/10 [==============================] - 7s 695ms/step - g_loss: 0.6751 - d_loss: 0.6953
# Epoch 1378/1500
# 10/10 [==============================] - 7s 704ms/step - g_loss: 0.6789 - d_loss: 0.6971
# Epoch 1379/1500
# 10/10 [==============================] - 7s 684ms/step - g_loss: 0.6858 - d_loss: 0.6928
# Epoch 1380/1500
# 10/10 [==============================] - 7s 710ms/step - g_loss: 0.6912 - d_loss: 0.6933
# Epoch 1381/1500
# 10/10 [==============================] - 7s 688ms/step - g_loss: 0.6954 - d_loss: 0.6946
# Epoch 1382/1500
# 10/10 [==============================] - 7s 703ms/step - g_loss: 0.7009 - d_loss: 0.6888
# Epoch 1383/1500
# 10/10 [==============================] - 7s 693ms/step - g_loss: 0.7046 - d_loss: 0.6912
# Epoch 1384/1500
# 10/10 [==============================] - 7s 705ms/step - g_loss: 0.7077 - d_loss: 0.6901
# Epoch 1385/1500
# 10/10 [==============================] - 7s 698ms/step - g_loss: 0.7101 - d_loss: 0.6881
# Epoch 1386/1500
# 10/10 [==============================] - 7s 689ms/step - g_loss: 0.7145 - d_loss: 0.6877
# Epoch 1387/1500
# 10/10 [==============================] - 7s 712ms/step - g_loss: 0.7174 - d_loss: 0.6872
# Epoch 1388/1500
# 10/10 [==============================] - 7s 690ms/step - g_loss: 0.7206 - d_loss: 0.6868
# Epoch 1389/1500
# 10/10 [==============================] - 7s 709ms/step - g_loss: 0.7222 - d_loss: 0.6863
# Epoch 1390/1500
# 10/10 [==============================] - 7s 711ms/step - g_loss: 0.7257 - d_loss: 0.6847
# Epoch 1391/1500
# 10/10 [==============================] - 7s 711ms/step - g_loss: 0.7259 - d_loss: 0.6826
# Epoch 1392/1500
# 10/10 [==============================] - 7s 718ms/step - g_loss: 0.7271 - d_loss: 0.6831
# Epoch 1393/1500
# 10/10 [==============================] - 7s 707ms/step - g_loss: 0.7290 - d_loss: 0.6822
# Epoch 1394/1500
# 10/10 [==============================] - 7s 695ms/step - g_loss: 0.7320 - d_loss: 0.6821
# Epoch 1395/1500
# 10/10 [==============================] - 7s 690ms/step - g_loss: 0.7347 - d_loss: 0.6800
# Epoch 1396/1500
# 10/10 [==============================] - 7s 708ms/step - g_loss: 0.7336 - d_loss: 0.6812
# Epoch 1397/1500
# 10/10 [==============================] - 7s 687ms/step - g_loss: 0.7371 - d_loss: 0.6794
# Epoch 1398/1500
# 10/10 [==============================] - 7s 711ms/step - g_loss: 0.7380 - d_loss: 0.6789
# Epoch 1399/1500
# 10/10 [==============================] - 7s 691ms/step - g_loss: 0.7404 - d_loss: 0.6806
# Epoch 1400/1500
# 10/10 [==============================] - 7s 706ms/step - g_loss: 0.7422 - d_loss: 0.6797
# Epoch 1401/1500
# 10/10 [==============================] - 7s 692ms/step - g_loss: 0.7451 - d_loss: 0.6778
# Epoch 1402/1500
# 10/10 [==============================] - 7s 696ms/step - g_loss: 0.7439 - d_loss: 0.6790
# Epoch 1403/1500
# 10/10 [==============================] - 7s 700ms/step - g_loss: 0.7466 - d_loss: 0.6788
# Epoch 1404/1500
# 10/10 [==============================] - 7s 683ms/step - g_loss: 0.7473 - d_loss: 0.6756
# Epoch 1405/1500
# 10/10 [==============================] - 7s 706ms/step - g_loss: 0.7465 - d_loss: 0.6773
# Epoch 1406/1500
# 10/10 [==============================] - 7s 687ms/step - g_loss: 0.7473 - d_loss: 0.6771
# Epoch 1407/1500
# 10/10 [==============================] - 7s 716ms/step - g_loss: 0.7484 - d_loss: 0.6746
# Epoch 1408/1500
# 10/10 [==============================] - 7s 688ms/step - g_loss: 0.7476 - d_loss: 0.6731
# Epoch 1409/1500
# 10/10 [==============================] - 7s 707ms/step - g_loss: 0.7476 - d_loss: 0.6718
# Epoch 1410/1500
# 10/10 [==============================] - 7s 692ms/step - g_loss: 0.7487 - d_loss: 0.6758
# Epoch 1411/1500
# 10/10 [==============================] - 7s 699ms/step - g_loss: 0.7484 - d_loss: 0.6738
# Epoch 1412/1500
# 10/10 [==============================] - 7s 698ms/step - g_loss: 0.7495 - d_loss: 0.6716
# Epoch 1413/1500
# 10/10 [==============================] - 7s 684ms/step - g_loss: 0.7492 - d_loss: 0.6724
# Epoch 1414/1500
# 10/10 [==============================] - 7s 721ms/step - g_loss: 0.7486 - d_loss: 0.6707
# Epoch 1415/1500
# 10/10 [==============================] - 7s 687ms/step - g_loss: 0.7468 - d_loss: 0.6721
# Epoch 1416/1500
# 10/10 [==============================] - 7s 711ms/step - g_loss: 0.7499 - d_loss: 0.6694
# Epoch 1417/1500
# 10/10 [==============================] - 7s 695ms/step - g_loss: 0.7491 - d_loss: 0.6701
# Epoch 1418/1500
# 10/10 [==============================] - 7s 709ms/step - g_loss: 0.7486 - d_loss: 0.6688
# Epoch 1419/1500
# 10/10 [==============================] - 7s 701ms/step - g_loss: 0.7488 - d_loss: 0.6710
# Epoch 1420/1500
# 10/10 [==============================] - 7s 694ms/step - g_loss: 0.7475 - d_loss: 0.6693
# Epoch 1421/1500
# 10/10 [==============================] - 7s 707ms/step - g_loss: 0.7469 - d_loss: 0.6675
# Epoch 1422/1500
# 10/10 [==============================] - 7s 689ms/step - g_loss: 0.7460 - d_loss: 0.6671
# Epoch 1423/1500
# 10/10 [==============================] - 7s 715ms/step - g_loss: 0.7451 - d_loss: 0.6672
# Epoch 1424/1500
# 10/10 [==============================] - 7s 684ms/step - g_loss: 0.7431 - d_loss: 0.6641
# Epoch 1425/1500
# 10/10 [==============================] - 7s 710ms/step - g_loss: 0.7460 - d_loss: 0.6680
# Epoch 1426/1500
# 10/10 [==============================] - 7s 691ms/step - g_loss: 0.7434 - d_loss: 0.6660
# Epoch 1427/1500
# 10/10 [==============================] - 7s 702ms/step - g_loss: 0.7451 - d_loss: 0.6659
# Epoch 1428/1500
# 10/10 [==============================] - 7s 693ms/step - g_loss: 0.7446 - d_loss: 0.6646
# Epoch 1429/1500
# 10/10 [==============================] - 7s 690ms/step - g_loss: 0.7451 - d_loss: 0.6637
# Epoch 1430/1500
# 10/10 [==============================] - 7s 705ms/step - g_loss: 0.7442 - d_loss: 0.6657
# Epoch 1431/1500
# 10/10 [==============================] - 7s 687ms/step - g_loss: 0.7447 - d_loss: 0.6631
# Epoch 1432/1500
# 10/10 [==============================] - 7s 714ms/step - g_loss: 0.7439 - d_loss: 0.6659
# Epoch 1433/1500
# 10/10 [==============================] - 7s 701ms/step - g_loss: 0.7436 - d_loss: 0.6635
# Epoch 1434/1500
# 10/10 [==============================] - 7s 712ms/step - g_loss: 0.7435 - d_loss: 0.6660
# Epoch 1435/1500
# 10/10 [==============================] - 7s 694ms/step - g_loss: 0.7432 - d_loss: 0.6629
# Epoch 1436/1500
# 10/10 [==============================] - 7s 708ms/step - g_loss: 0.7440 - d_loss: 0.6640
# Epoch 1437/1500
# 10/10 [==============================] - 7s 700ms/step - g_loss: 0.7428 - d_loss: 0.6661
# Epoch 1438/1500
# 10/10 [==============================] - 7s 696ms/step - g_loss: 0.7417 - d_loss: 0.6627
# Epoch 1439/1500
# 10/10 [==============================] - 7s 712ms/step - g_loss: 0.7423 - d_loss: 0.6653
# Epoch 1440/1500
# 10/10 [==============================] - 7s 689ms/step - g_loss: 0.7429 - d_loss: 0.6635
# Epoch 1441/1500
# 10/10 [==============================] - 7s 723ms/step - g_loss: 0.7405 - d_loss: 0.6622
# Epoch 1442/1500
# 10/10 [==============================] - 7s 692ms/step - g_loss: 0.7406 - d_loss: 0.6666
# Epoch 1443/1500
# 10/10 [==============================] - 7s 714ms/step - g_loss: 0.7400 - d_loss: 0.6648
# Epoch 1444/1500
# 10/10 [==============================] - 7s 700ms/step - g_loss: 0.7385 - d_loss: 0.6651
# Epoch 1445/1500
# 10/10 [==============================] - 7s 702ms/step - g_loss: 0.7378 - d_loss: 0.6620
# Epoch 1446/1500
# 10/10 [==============================] - 7s 702ms/step - g_loss: 0.7360 - d_loss: 0.6642
# Epoch 1447/1500
# 10/10 [==============================] - 7s 696ms/step - g_loss: 0.7364 - d_loss: 0.6626
# Epoch 1448/1500
# 10/10 [==============================] - 7s 714ms/step - g_loss: 0.7354 - d_loss: 0.6636
# Epoch 1449/1500
# 10/10 [==============================] - 7s 689ms/step - g_loss: 0.7358 - d_loss: 0.6642
# Epoch 1450/1500
# 10/10 [==============================] - 7s 716ms/step - g_loss: 0.7370 - d_loss: 0.6638
# Epoch 1451/1500
# 10/10 [==============================] - 7s 694ms/step - g_loss: 0.7339 - d_loss: 0.6673
# Epoch 1452/1500
# 10/10 [==============================] - 7s 714ms/step - g_loss: 0.7324 - d_loss: 0.6658
# Epoch 1453/1500
# 10/10 [==============================] - 7s 692ms/step - g_loss: 0.7300 - d_loss: 0.6633
# Epoch 1454/1500
# 10/10 [==============================] - 7s 709ms/step - g_loss: 0.7279 - d_loss: 0.6691
# Epoch 1455/1500
# 10/10 [==============================] - 7s 697ms/step - g_loss: 0.7249 - d_loss: 0.6680
# Epoch 1456/1500
# 10/10 [==============================] - 7s 696ms/step - g_loss: 0.7206 - d_loss: 0.6682
# Epoch 1457/1500
# 10/10 [==============================] - 7s 710ms/step - g_loss: 0.7162 - d_loss: 0.6697
# Epoch 1458/1500
# 10/10 [==============================] - 7s 691ms/step - g_loss: 0.7137 - d_loss: 0.6703
# Epoch 1459/1500
# 10/10 [==============================] - 7s 720ms/step - g_loss: 0.7111 - d_loss: 0.6718
# Epoch 1460/1500
# 10/10 [==============================] - 7s 692ms/step - g_loss: 0.7083 - d_loss: 0.6715
# Epoch 1461/1500
# 10/10 [==============================] - 7s 718ms/step - g_loss: 0.7063 - d_loss: 0.6697
# Epoch 1462/1500
# 10/10 [==============================] - 7s 697ms/step - g_loss: 0.7050 - d_loss: 0.6749
# Epoch 1463/1500
# 10/10 [==============================] - 7s 703ms/step - g_loss: 0.7032 - d_loss: 0.6759
# Epoch 1464/1500
# 10/10 [==============================] - 7s 702ms/step - g_loss: 0.6991 - d_loss: 0.6745
# Epoch 1465/1500
# 10/10 [==============================] - 7s 697ms/step - g_loss: 0.6957 - d_loss: 0.6804
# Epoch 1466/1500
# 10/10 [==============================] - 7s 710ms/step - g_loss: 0.6922 - d_loss: 0.6774
# Epoch 1467/1500
# 10/10 [==============================] - 7s 690ms/step - g_loss: 0.6870 - d_loss: 0.6838
# Epoch 1468/1500
# 10/10 [==============================] - 7s 714ms/step - g_loss: 0.6816 - d_loss: 0.6860
# Epoch 1469/1500
# 10/10 [==============================] - 7s 690ms/step - g_loss: 0.6759 - d_loss: 0.6869
# Epoch 1470/1500
# 10/10 [==============================] - 7s 714ms/step - g_loss: 0.6710 - d_loss: 0.6887
# Epoch 1471/1500
# 10/10 [==============================] - 7s 699ms/step - g_loss: 0.6649 - d_loss: 0.6969
# Epoch 1472/1500
# 10/10 [==============================] - 7s 707ms/step - g_loss: 0.6608 - d_loss: 0.6990
# Epoch 1473/1500
# 10/10 [==============================] - 7s 711ms/step - g_loss: 0.6560 - d_loss: 0.7032
# Epoch 1474/1500
# 10/10 [==============================] - 7s 691ms/step - g_loss: 0.6546 - d_loss: 0.7017
# Epoch 1475/1500
# 10/10 [==============================] - 7s 712ms/step - g_loss: 0.6558 - d_loss: 0.7055
# Epoch 1476/1500
# 10/10 [==============================] - 7s 689ms/step - g_loss: 0.6585 - d_loss: 0.7047
# Epoch 1477/1500
# 10/10 [==============================] - 7s 718ms/step - g_loss: 0.6627 - d_loss: 0.7036
# Epoch 1478/1500
# 10/10 [==============================] - 7s 692ms/step - g_loss: 0.6678 - d_loss: 0.7025
# Epoch 1479/1500
# 10/10 [==============================] - 7s 713ms/step - g_loss: 0.6724 - d_loss: 0.7017
# Epoch 1480/1500
# 10/10 [==============================] - 7s 694ms/step - g_loss: 0.6770 - d_loss: 0.6967
# Epoch 1481/1500
# 10/10 [==============================] - 7s 708ms/step - g_loss: 0.6845 - d_loss: 0.6977
# Epoch 1482/1500
# 10/10 [==============================] - 7s 702ms/step - g_loss: 0.6889 - d_loss: 0.6958
# Epoch 1483/1500
# 10/10 [==============================] - 7s 692ms/step - g_loss: 0.6944 - d_loss: 0.6925
# Epoch 1484/1500
# 10/10 [==============================] - 7s 694ms/step - g_loss: 0.6971 - d_loss: 0.6901
# Epoch 1485/1500
# 10/10 [==============================] - 7s 672ms/step - g_loss: 0.7013 - d_loss: 0.6897
# Epoch 1486/1500
# 10/10 [==============================] - 7s 691ms/step - g_loss: 0.7043 - d_loss: 0.6889
# Epoch 1487/1500
# 10/10 [==============================] - 7s 670ms/step - g_loss: 0.7082 - d_loss: 0.6829
# Epoch 1488/1500
# 10/10 [==============================] - 7s 680ms/step - g_loss: 0.7117 - d_loss: 0.6834
# Epoch 1489/1500
# 10/10 [==============================] - 7s 670ms/step - g_loss: 0.7141 - d_loss: 0.6758
# Epoch 1490/1500
# 10/10 [==============================] - 7s 672ms/step - g_loss: 0.7173 - d_loss: 0.6711
# Epoch 1491/1500
# 10/10 [==============================] - 7s 689ms/step - g_loss: 0.7211 - d_loss: 0.6737
# Epoch 1492/1500
# 10/10 [==============================] - 7s 664ms/step - g_loss: 0.7245 - d_loss: 0.6708
# Epoch 1493/1500
# 10/10 [==============================] - 7s 693ms/step - g_loss: 0.7279 - d_loss: 0.6678
# Epoch 1494/1500
# 10/10 [==============================] - 7s 674ms/step - g_loss: 0.7307 - d_loss: 0.6694
# Epoch 1495/1500
# 10/10 [==============================] - 7s 686ms/step - g_loss: 0.7316 - d_loss: 0.6648
# Epoch 1496/1500
# 10/10 [==============================] - 7s 689ms/step - g_loss: 0.7348 - d_loss: 0.6571
# Epoch 1497/1500
# 10/10 [==============================] - 7s 691ms/step - g_loss: 0.7387 - d_loss: 0.6591
# Epoch 1498/1500
# 10/10 [==============================] - 7s 683ms/step - g_loss: 0.7404 - d_loss: 0.6550
# Epoch 1499/1500
# 10/10 [==============================] - 7s 674ms/step - g_loss: 0.7435 - d_loss: 0.6559
# Epoch 1500/1500
# 10/10 [==============================] - 7s 697ms/step - g_loss: 0.7435 - d_loss: 0.6516

# %%
#Set Global Random Seed
np.random.seed(8)
Gen_Labels = np.zeros(3000)
Gen_Labels[1000:2000] = 1
Gen_Labels[2000:] = 2
Gen_Labels.astype(np.int32)
# Out:
# array([0, 0, 0, ..., 2, 2, 2])

# %%
#Generate data using generative models (1000 for each class)
#Subsequent random forest models partially refer to "RCGAN Random forest.ipynb"
z = np.concatenate([np.random.randn(3000,38),keras.utils.to_categorical(Gen_Labels,3)],axis=1)


Gen_Data = generator(z)
Gen_Data = Gen_Data.numpy()
Gen_Data = scaler.inverse_transform(Gen_Data)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
#Compute the cumulative value of the five input variables as a feature of the real dataset
features_names = ['CarbonSequestration','FinalEnergy_Liquid','PrimaryEnergy_Coal','PrimaryEnergy_Gas','PrimaryEnergy_Oil','SecondaryEle_Nuclear',
                 'SecondaryEle_Oil','SecondaryEle_Solar','SecondaryEle_Wind','SecondaryEle_Hydro','SecondaryEle_Geothermal','SecondaryEle_Gas',
                 'SecondaryEle_Coal','SecondaryEle_Biomass','SecondaryEle']

Real_Data_Sum = np.zeros((data_num,nft-1))
for i in range(data_num):#data_num :amount of data
    for j in range(nft-1):# feature dimension
        for k in range(8):#time step
            Real_Data_Sum[i][j] += (X[i,k,j] + X[i,k+1,j]) * 5

# %%
Real_DataSet = pd.DataFrame(Real_Data_Sum,columns=features_names)

# %%
#Construct the feature matrix of the feature cumulative values of the generated dataset
Gen_Data_Sum = np.zeros((3000,nft-1))
for i in range(3000):#3000 :amount of data
    for j in range(nft-1):# ：feature dimension
        for k in range(8):#time step
            Gen_Data_Sum[i][j] += (Gen_Data[i,k,j] + Gen_Data[i,k+1,j]) * 5

# %%
Gen_DataSet = pd.DataFrame(Gen_Data_Sum,columns=features_names)

# %%
#First train the model with real datasets to predict the generated data.Cross-validation using grid search
R_G = RandomForestClassifier(random_state=42)
parameters_1 = {
    'n_estimators':[10,100,500,1000],
    'max_depth':[6,8,10,12,14,16],
    'min_samples_split':[3,4,5,6]
}

# %%
clf_RG = GridSearchCV(R_G,parameters_1,cv=3,n_jobs=-1,verbose=2)

# %%
clf_RG.fit(Real_DataSet,Y)
# Out:
# Fitting 3 folds for each of 96 candidates, totalling 288 fits
# GridSearchCV(cv=3, estimator=RandomForestClassifier(random_state=42), n_jobs=-1,
#              param_grid={'max_depth': [6, 8, 10, 12, 14, 16],
#                          'min_samples_split': [3, 4, 5, 6],
#                          'n_estimators': [10, 100, 500, 1000]},
#              verbose=2)

# %%
print('Best parameters found:')
print(clf_RG.best_params_)
# Out:
# Best parameters found:
# {'max_depth': 8, 'min_samples_split': 3, 'n_estimators': 500}

# %%
y_pred = clf_RG.predict(Real_DataSet)
print(f"Test results on the training dataset：")
print(classification_report(Y,y_pred,target_names=['C1234','C56','C78']))
# Out:
# Test results on the training dataset：
#               precision    recall  f1-score   support
#
#        C1234       1.00      1.00      1.00       554
#          C56       0.99      1.00      1.00       237
#          C78       1.00      0.98      0.99       110
#
#     accuracy                           1.00       901
#    macro avg       1.00      0.99      1.00       901
# weighted avg       1.00      1.00      1.00       901

# %%
y_pred = clf_RG.predict(Gen_DataSet)
print(f"Test results on the test set：")
print(classification_report(Gen_Labels,y_pred,target_names=['C1234','C56','C78']))
# Out:
# Test results on the test set：
#               precision    recall  f1-score   support
#
#        C1234       1.00      1.00      1.00      1000
#          C56       1.00      0.99      1.00      1000
#          C78       1.00      1.00      1.00      1000
#
#     accuracy                           1.00      3000
#    macro avg       1.00      1.00      1.00      3000
# weighted avg       1.00      1.00      1.00      3000

# %%
#Use the generated dataset to train models to predict real data
G_R = RandomForestClassifier(random_state=42)
parameters_2 = {
    'n_estimators':[10,100,200,500,1000],
    'max_depth':[6,8,10,12,14,16],
    'min_samples_split':[3,4,5,6]
}

# %%
clf_GR = GridSearchCV(G_R,parameters_2,cv=3,n_jobs=-1,verbose=2)

# %%
clf_GR.fit(Gen_DataSet,Gen_Labels)
print('Best parameters found:')
print(clf_GR.best_params_)
# Out:
# Fitting 3 folds for each of 120 candidates, totalling 360 fits
# Best parameters found:
# {'max_depth': 6, 'min_samples_split': 3, 'n_estimators': 10}

# %%
y_pred = clf_GR.predict(Gen_DataSet)
print(f"Test results on the training dataset：")
print(classification_report(Gen_Labels,y_pred,target_names=['C1234','C56','C78']))
# Out:
# Test results on the training dataset：
#               precision    recall  f1-score   support
#
#        C1234       1.00      1.00      1.00      1000
#          C56       1.00      1.00      1.00      1000
#          C78       1.00      1.00      1.00      1000
#
#     accuracy                           1.00      3000
#    macro avg       1.00      1.00      1.00      3000
# weighted avg       1.00      1.00      1.00      3000

# %%
y_pred = clf_GR.predict(Real_DataSet)
print(f"Test results on the test set：")
print(classification_report(Y,y_pred,target_names=['C1234','C56','C78']))
# Out:
# Test results on the test set：
#               precision    recall  f1-score   support
#
#        C1234       0.93      0.70      0.80       554
#          C56       0.75      0.53      0.62       237
#          C78       0.34      0.97      0.50       110
#
#     accuracy                           0.69       901
#    macro avg       0.67      0.73      0.64       901
# weighted avg       0.81      0.69      0.72       901

# %%
generator.save_weights('Policy-SecondaryEle-CGAN_generator.h5')
discriminator.save_weights('Policy-SecondaryEle-CGAN_discriminator.h5')

# %%
#Generate 30000 samples
Gen_Labels = np.zeros(30000)
Gen_Labels[10000:20000] = 1
Gen_Labels[20000:] = 2
Gen_Labels.astype(np.int32)
# Out:
# array([0, 0, 0, ..., 2, 2, 2])

# %%
#Generate data using generative models (10000 for each class)
#Subsequent random forest models partially refer to "RCGAN Random forest.ipynb"
z = np.concatenate([np.random.randn(30000,38),keras.utils.to_categorical(Gen_Labels,3)],axis=1)

start = time.time()
Gen_Data = generator(z)
Gen_Data = Gen_Data.numpy()
Gen_Data = scaler.inverse_transform(Gen_Data)

end = time.time()
runtime = end - start
with open('Runtime.txt', 'a') as f:
    f.write(f'CGAN-SecondaryEle-data generate time: {runtime:.4f} sec\n')
